# %% [markdown]
# Problem Statement:
# In this project, initially you need to preprocess the data and then develop an
# understanding of the different features of the data by performing exploratory
# analysis and creating visualizations. Further, after having sufficient knowledge
# about the attributes, you will perform a predictive task of classification to predict
# whether an individual makes over 50,000 a year or less by using different
# machine learning algorithms.
#
# Tasks To Be Performed:
# 1. Perform Exploratory Data Analysis to find key insights.
# 2. Use various machine learning algorithms to predict the response variable.

# %%
import pandas as pd

# %%
df = pd.read_csv('census-income .csv')
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32556  Married-civ-spouse       Tech-support           Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32558             Widowed       Adm-clerical      Unmarried  White  Female
# 32559       Never-married       Adm-clerical      Own-child  White    Male
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country annual_income
# 0              2174             0              40  United-States         <=50K
# 1                 0             0              13  United-States         <=50K
# 2                 0             0              40  United-States         <=50K
# 3                 0             0              40  United-States         <=50K
# 4                 0             0              40           Cuba         <=50K
# ...             ...           ...             ...            ...           ...
# 32556             0             0              38  United-States         <=50K
# 32557             0             0              40  United-States          >50K
# 32558             0             0              40  United-States         <=50K
# 32559             0             0              20  United-States         <=50K
# 32560         15024             0              40  United-States          >50K
#
# [32561 rows x 15 columns]

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.describe(include = 'O')
# Out:
#        workclass education      marital-status      occupation relationship  \
# count      32561     32561               32561           32561        32561
# unique         9        16                   7              15            6
# top      Private   HS-grad  Married-civ-spouse  Prof-specialty      Husband
# freq       22696     10501               14976            4140        13193
#
#          race    sex native-country annual_income
# count   32561  32561          32561         32561
# unique      5      2             42             2
# top     White   Male  United-States         <=50K
# freq    27816  21790          29170         24720

# %%
df.describe(include = 'all')
# Out:
#                  age workclass        fnlwgt education  education-num  \
# count   32561.000000     32561  3.256100e+04     32561   32561.000000
# unique           NaN         9           NaN        16            NaN
# top              NaN   Private           NaN   HS-grad            NaN
# freq             NaN     22696           NaN     10501            NaN
# mean       38.581647       NaN  1.897784e+05       NaN      10.080679
# std        13.640433       NaN  1.055500e+05       NaN       2.572720
# min        17.000000       NaN  1.228500e+04       NaN       1.000000
# 25%        28.000000       NaN  1.178270e+05       NaN       9.000000
# 50%        37.000000       NaN  1.783560e+05       NaN      10.000000
# 75%        48.000000       NaN  2.370510e+05       NaN      12.000000
# max        90.000000       NaN  1.484705e+06       NaN      16.000000
#
#             marital-status      occupation relationship   race    sex  \
# count                32561           32561        32561  32561  32561
# unique                   7              15            6      5      2
# top     Married-civ-spouse  Prof-specialty      Husband  White   Male
# freq                 14976            4140        13193  27816  21790
# mean                   NaN             NaN          NaN    NaN    NaN
# std                    NaN             NaN          NaN    NaN    NaN
# min                    NaN             NaN          NaN    NaN    NaN
# 25%                    NaN             NaN          NaN    NaN    NaN
# 50%                    NaN             NaN          NaN    NaN    NaN
# 75%                    NaN             NaN          NaN    NaN    NaN
# max                    NaN             NaN          NaN    NaN    NaN
#
#         capital-gain  capital-loss  hours-per-week native-country  \
# count   32561.000000  32561.000000    32561.000000          32561
# unique           NaN           NaN             NaN             42
# top              NaN           NaN             NaN  United-States
# freq             NaN           NaN             NaN          29170
# mean     1077.648844     87.303830       40.437456            NaN
# std      7385.292085    402.960219       12.347429            NaN
# min         0.000000      0.000000        1.000000            NaN
# 25%         0.000000      0.000000       40.000000            NaN
# 50%         0.000000      0.000000       40.000000            NaN
# 75%         0.000000      0.000000       45.000000            NaN
# max     99999.000000   4356.000000       99.000000            NaN
#
#        annual_income
# count          32561
# unique             2
# top            <=50K
# freq           24720
# mean             NaN
# std              NaN
# min              NaN
# 25%              NaN
# 50%              NaN
# 75%              NaN
# max              NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  annual_income   32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# annual_income     0
# dtype: int64

# %%
df.head(2)
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
#
#        marital-status       occupation   relationship   race   sex  \
# 0       Never-married     Adm-clerical  Not-in-family  White  Male
# 1  Married-civ-spouse  Exec-managerial        Husband  White  Male
#
#    capital-gain  capital-loss  hours-per-week native-country annual_income
# 0          2174             0              40  United-States         <=50K
# 1             0             0              13  United-States         <=50K

# %%
df['workclass'].unique()
# Out:
# array(['State-gov', 'Self-emp-not-inc', 'Private', 'Federal-gov',
#        'Local-gov', '?', 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
df['marital-status'].unique()
# Out:
# array(['Never-married', 'Married-civ-spouse', 'Divorced',
#        'Married-spouse-absent', 'Separated', 'Married-AF-spouse',
#        'Widowed'], dtype=object)

# %%
df['occupation'].unique()
# Out:
# array(['Adm-clerical', 'Exec-managerial', 'Handlers-cleaners',
#        'Prof-specialty', 'Other-service', 'Sales', 'Craft-repair',
#        'Transport-moving', 'Farming-fishing', 'Machine-op-inspct',
#        'Tech-support', '?', 'Protective-serv', 'Armed-Forces',
#        'Priv-house-serv'], dtype=object)

# %%
df['occupation'].nunique()
# Out:
# 15

# %%
import numpy as np
df = df.replace('?',np.nan)

# %%
df.isna().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     583
# annual_income        0
# dtype: int64

# %%
#filling null values with mode.
df['workclass'].fillna(df['workclass'].mode()[0], inplace = True)

# %%
df.isna().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     583
# annual_income        0
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# annual_income     0
# dtype: int64

# %%
df.shape
# Out:
# (30162, 15)

# %%
df.duplicated().sum()
# Out:
# 23

# %%
df.drop_duplicates(inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30139 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             30139 non-null  int64
#  1   workclass       30139 non-null  object
#  2   fnlwgt          30139 non-null  int64
#  3   education       30139 non-null  object
#  4   education-num   30139 non-null  int64
#  5   marital-status  30139 non-null  object
#  6   occupation      30139 non-null  object
#  7   relationship    30139 non-null  object
#  8   race            30139 non-null  object
#  9   sex             30139 non-null  object
#  10  capital-gain    30139 non-null  int64
#  11  capital-loss    30139 non-null  int64
#  12  hours-per-week  30139 non-null  int64
#  13  native-country  30139 non-null  object
#  14  annual_income   30139 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
#finding the outliers
import matplotlib.pyplot as plt
import seaborn as sns

for col in df.columns:
  if df[col].dtype != 'object':
    sns.boxplot(df[col])
    plt.title(col)
    plt.show()

# %%
for i in df.columns:
  if df[i].dtype != 'object':
    Q1=df[i].quantile(0.25)
    Q3=df[i].quantile(0.75)
    IQR=Q3-Q1
    LL = Q1 - 1.5*IQR
    UL = Q3 + 1.5*IQR
    df = df[(df[i] >= LL ) & (df[i] <= UL)]

# %%
for col in df.columns:
  if df[col].dtype != 'object':
    sns.boxplot(df[col])
    plt.title(col)
    plt.show()

# %%
df.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# annual_income     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18445 entries, 2 to 32558
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             18445 non-null  int64
#  1   workclass       18445 non-null  object
#  2   fnlwgt          18445 non-null  int64
#  3   education       18445 non-null  object
#  4   education-num   18445 non-null  int64
#  5   marital-status  18445 non-null  object
#  6   occupation      18445 non-null  object
#  7   relationship    18445 non-null  object
#  8   race            18445 non-null  object
#  9   sex             18445 non-null  object
#  10  capital-gain    18445 non-null  int64
#  11  capital-loss    18445 non-null  int64
#  12  hours-per-week  18445 non-null  int64
#  13  native-country  18445 non-null  object
#  14  annual_income   18445 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 2.3+ MB

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'annual_income'],
#       dtype='object')

# %%
le = LabelEncoder()

# %%
for col in df.columns:
  if df[col].dtype == 'object':
    df[col] = le.fit_transform(df[col])

# %%
df.head()
# Out:
#    age  workclass  fnlwgt  education  education-num  marital-status  \
# 2   38          2  215646         10              9               0
# 3   53          2  234721          1              7               2
# 4   28          2  338409          8             13               2
# 5   37          2  284582         11             14               2
# 7   52          4  209642         10              9               2
#
#    occupation  relationship  race  sex  capital-gain  capital-loss  \
# 2           5             1     4    1             0             0
# 3           5             0     2    1             0             0
# 4           9             5     2    0             0             0
# 5           3             5     4    0             0             0
# 7           3             0     4    1             0             0
#
#    hours-per-week  native-country  annual_income
# 2              40              37              0
# 3              40              37              0
# 4              40               4              0
# 5              40              37              0
# 7              45              37              1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18445 entries, 2 to 32558
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             18445 non-null  int64
#  1   workclass       18445 non-null  int32
#  2   fnlwgt          18445 non-null  int64
#  3   education       18445 non-null  int32
#  4   education-num   18445 non-null  int64
#  5   marital-status  18445 non-null  int32
#  6   occupation      18445 non-null  int32
#  7   relationship    18445 non-null  int32
#  8   race            18445 non-null  int32
#  9   sex             18445 non-null  int32
#  10  capital-gain    18445 non-null  int64
#  11  capital-loss    18445 non-null  int64
#  12  hours-per-week  18445 non-null  int64
#  13  native-country  18445 non-null  int32
#  14  annual_income   18445 non-null  int32
# dtypes: int32(9), int64(6)
# memory usage: 1.6 MB

# %%
cor = df.corr()
cor
# Out:
#                      age  workclass    fnlwgt  education  education-num  \
# age             1.000000   0.050859 -0.072423  -0.032520       0.004677
# workclass       0.050859   1.000000 -0.027064  -0.000467       0.024732
# fnlwgt         -0.072423  -0.027064  1.000000  -0.019127      -0.036239
# education      -0.032520  -0.000467 -0.019127   1.000000       0.323674
# education-num   0.004677   0.024732 -0.036239   0.323674       1.000000
# marital-status -0.286344  -0.019961  0.036056  -0.016904      -0.007637
# occupation      0.001840   0.025688 -0.002604  -0.043108       0.099802
# relationship   -0.203929  -0.054632  0.007055   0.015943      -0.055750
# race            0.012243   0.043242 -0.004913   0.010328       0.023433
# sex             0.048907   0.059168  0.019565  -0.041142      -0.028673
# capital-gain         NaN        NaN       NaN        NaN            NaN
# capital-loss         NaN        NaN       NaN        NaN            NaN
# hours-per-week  0.044904   0.055339 -0.019828   0.034296       0.127261
# native-country  0.000140   0.006243 -0.066972   0.088335       0.066035
# annual_income   0.234244  -0.003205 -0.002206   0.062281       0.291777
#
#                 marital-status  occupation  relationship      race       sex  \
# age                  -0.286344    0.001840     -0.203929  0.012243  0.048907
# workclass            -0.019961    0.025688     -0.054632  0.043242  0.059168
# fnlwgt                0.036056   -0.002604      0.007055 -0.004913  0.019565
# education            -0.016904   -0.043108      0.015943  0.010328 -0.041142
# education-num        -0.007637    0.099802     -0.055750  0.023433 -0.028673
# marital-status        1.000000    0.025057      0.143070 -0.074820 -0.072101
# occupation            0.025057    1.000000     -0.075816  0.003994  0.090105
# relationship          0.143070   -0.075816      1.000000 -0.124913 -0.578857
# race                 -0.074820    0.003994     -0.124913  1.000000  0.103012
# sex                  -0.072101    0.090105     -0.578857  0.103012  1.000000
# capital-gain               NaN         NaN           NaN       NaN       NaN
# capital-loss               NaN         NaN           NaN       NaN       NaN
# hours-per-week       -0.081467    0.067100     -0.171275  0.092992  0.172992
# native-country       -0.022957   -0.002167     -0.016668  0.130059  0.007115
# annual_income        -0.157503    0.057642     -0.227063  0.070763  0.198526
#
#                 capital-gain  capital-loss  hours-per-week  native-country  \
# age                      NaN           NaN        0.044904        0.000140
# workclass                NaN           NaN        0.055339        0.006243
# fnlwgt                   NaN           NaN       -0.019828       -0.066972
# education                NaN           NaN        0.034296        0.088335
# education-num            NaN           NaN        0.127261        0.066035
# marital-status           NaN           NaN       -0.081467       -0.022957
# occupation               NaN           NaN        0.067100       -0.002167
# relationship             NaN           NaN       -0.171275       -0.016668
# race                     NaN           NaN        0.092992        0.130059
# sex                      NaN           NaN        0.172992        0.007115
# capital-gain             NaN           NaN             NaN             NaN
# capital-loss             NaN           NaN             NaN             NaN
# hours-per-week           NaN           NaN        1.000000        0.025236
# native-country           NaN           NaN        0.025236        1.000000
# annual_income            NaN           NaN        0.172628        0.009215
#
#                 annual_income
# age                  0.234244
# workclass           -0.003205
# fnlwgt              -0.002206
# education            0.062281
# education-num        0.291777
# marital-status      -0.157503
# occupation           0.057642
# relationship        -0.227063
# race                 0.070763
# sex                  0.198526
# capital-gain              NaN
# capital-loss              NaN
# hours-per-week       0.172628
# native-country       0.009215
# annual_income        1.000000

# %%
#heatmap
plt.figure(figsize = (12,8))
sns.heatmap(cor, annot = True,cmap = 'Greens', fmt = ".2f")
# Out:
# <Axes: >

# %%
df.drop(columns = ['capital-gain', 'capital-loss'], inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18445 entries, 2 to 32558
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             18445 non-null  int64
#  1   workclass       18445 non-null  int32
#  2   fnlwgt          18445 non-null  int64
#  3   education       18445 non-null  int32
#  4   education-num   18445 non-null  int64
#  5   marital-status  18445 non-null  int32
#  6   occupation      18445 non-null  int32
#  7   relationship    18445 non-null  int32
#  8   race            18445 non-null  int32
#  9   sex             18445 non-null  int32
#  10  hours-per-week  18445 non-null  int64
#  11  native-country  18445 non-null  int32
#  12  annual_income   18445 non-null  int32
# dtypes: int32(9), int64(4)
# memory usage: 1.3 MB

# %% [markdown]
# **Model bulding**

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
x
# Out:
#        age  workclass  fnlwgt  education  education-num  marital-status  \
# 2       38          2  215646         10              9               0
# 3       53          2  234721          1              7               2
# 4       28          2  338409          8             13               2
# 5       37          2  284582         11             14               2
# 7       52          4  209642         10              9               2
# ...    ...        ...     ...        ...            ...             ...
# 32554   53          2  321865         11             14               2
# 32555   22          2  310152         13             10               4
# 32556   27          2  257302          6             12               2
# 32557   40          2  154374         10              9               2
# 32558   58          2  151910         10              9               6
#
#        occupation  relationship  race  sex  hours-per-week  native-country
# 2               5             1     4    1              40              37
# 3               5             0     2    1              40              37
# 4               9             5     2    0              40               4
# 5               3             5     4    0              40              37
# 7               3             0     4    1              45              37
# ...           ...           ...   ...  ...             ...             ...
# 32554           3             0     4    1              40              37
# 32555          10             1     4    1              40              37
# 32556          12             5     4    0              38              37
# 32557           6             0     4    1              40              37
# 32558           0             4     4    0              40              37
#
# [18445 rows x 12 columns]

# %%
y
# Out:
# 2        0
# 3        0
# 4        0
# 5        0
# 7        1
#         ..
# 32554    1
# 32555    0
# 32556    0
# 32557    1
# 32558    0
# Name: annual_income, Length: 18445, dtype: int32

# %%
#split into 80:20

from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state= 40)

# %% [markdown]
# **Logistic regression**

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# C:\Users\Payal Saket\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
pred = model.predict(x_test)
pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import *

# %%
acc = accuracy_score(y_test, pred)
acc
# Out:
# 0.7861208999728924

# %%
class_report = classification_report(y_test, pred)
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.96      0.88      2890
#            1       0.52      0.16      0.25       799
#
#     accuracy                           0.79      3689
#    macro avg       0.66      0.56      0.56      3689
# weighted avg       0.74      0.79      0.74      3689

# %%
confusion_matrix(y_test, pred)
# Out:
# array([[2770,  120],
#        [ 669,  130]], dtype=int64)

# %% [markdown]
# **Decision Tree**

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt_model = DecisionTreeClassifier()

# %%
dt_model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt_pred = dt_model.predict(x_test)

# %%
accuracy_score(y_test,dt_pred)
# Out:
# 0.7910002710761724

# %% [markdown]
# **Random Forest**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_model = RandomForestClassifier()

# %%
rf_model.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
rf_pred = rf_model.predict(x_test)
rf_pred
# Out:
# array([0, 1, 0, ..., 0, 0, 0])

# %%
accuracy_score(y_test,rf_pred)
# Out:
# 0.825426944971537

# %% [markdown]
# ### Inference:
# By analyzing the Census Income dataset, we built multiple classification models to predict whether an individual earns more than $50,000 per year. Among the models tested, the Random Forest Classifier performed the best with an accuracy of 82%. Features such as education level, hours worked per week, and occupation were found to be the most influential in predicting income."
